# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
X,y  = make_blobs(n_samples=500,n_features=2,centers=5, random_state=40)

# %%
plt.figure(0)
plt.grid(True)
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
Kmeans = KMeans(n_clusters=5)

# %%
Kmeans.fit(X)
# Out:
# KMeans(n_clusters=5)

# %%
Kmeans.cluster_centers_
# Out:
# array([[-0.85333139, -3.84153515],
#        [ 5.71197016,  3.69492309],
#        [ 5.76963426, -4.30242571],
#        [-1.88150144, -8.86976017],
#        [ 0.5328871 ,  2.59233799]])

# %%
plt.scatter(X[:,0],X[:,1])

plt.scatter(-0.85333139, -3.84153515, s=200, c = '#1f77b4')
plt.scatter( 5.71197016,  3.69492309, s=200, c = '#ff7f0e')
plt.scatter(5.76963426, -4.30242571, s=200, c = '#9467bd')
plt.scatter(-1.88150144, -8.86976017, s=200, c = '#e377c2')
plt.scatter(0.5328871 ,  2.59233799, s=200, c = '#e377c2')
plt.show()
